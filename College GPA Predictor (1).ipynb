# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("/Users/cdub/sat_gpa_v1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sat_sum  1000 non-null   int64
#  1   fy_gpa   1000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 15.8 KB

# %%
df.head()
# Out:
#    sat_sum  fy_gpa
# 0     1270    3.18
# 1     1220    3.33
# 2     1160    3.25
# 3      950    2.42
# 4     1070    2.63

# %%
df.describe()
# Out:
#            sat_sum       fy_gpa
# count  1000.000000  1000.000000
# mean   1033.290000     2.467950
# std     142.873681     0.740805
# min     530.000000     0.000000
# 25%     930.000000     1.980000
# 50%    1030.000000     2.465000
# 75%    1130.000000     3.020000
# max    1440.000000     4.000000

# %% [markdown]
# ### Scatter plot representing the relationship between GPA and SAT scores

# %%
plt.scatter(df["sat_sum"], df["fy_gpa"], c="#00f", marker="*",s=150, alpha=0.3)
plt.xlabel("SAT Score")
plt.ylabel ("Final Year GPA")
plt. title("Correlation between GPA & SAT Scores")
#
# Out:
# Text(0.5, 1.0, 'Correlation between GPA & SAT Scores')

# %%
sns.lmplot(x= "sat_sum", y= "fy_gpa", data=df)
plt.xlabel("SAT Summary")
plt.ylabel ("Final Year GPA")
plt. title("Correlation between GPA & SAT Scores")
# Out:
# Text(0.5, 1.0, 'Correlation between GPA & SAT Scores')

# %% [markdown]
# ### Defining Variables

# %%
x = df["sat_sum"]
y = df["fy_gpa"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(pd.DataFrame(x_train),pd.DataFrame(y_train))
# Out:
# LinearRegression()

# %%
# Test the Model's Performance
y_pred = model.predict(pd.DataFrame(x_test))

# %%
pd.DataFrame(y_pred)
# Out:
#             0
# 0    2.502613
# 1    2.030232
# 2    2.195565
# 3    2.455375
# 4    2.691565
# ..        ...
# 195  2.431756
# 196  2.620708
# 197  2.927755
# 198  2.290042
# 199  2.408137
#
# [200 rows x 1 columns]

# %%
y_test
# Out:
# 521    2.54
# 737    2.98
# 740    1.24
# 660    1.13
# 411    2.37
#        ...
# 408    3.16
# 332    3.13
# 208    3.19
# 613    2.04
# 78     2.67
# Name: fy_gpa, Length: 200, dtype: float64

# %%
# Measure the Accuracy of Our Model
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 0.4729588536459285
# R-squared: 0.20167022140686164

# %%
example_gpa = pd.DataFrame({
    "sat_sum" : [900]
})

# %%
model.predict(example_gpa)
# Out:
# array([[2.14832739]])

# %%
model.predict(pd.DataFrame([[900],[1200]]))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.14832739],
#        [2.85689798]])
